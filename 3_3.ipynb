# %% [markdown]
# # Nova seção

# %%
from google.colab import drive

# %%
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import pandas as pd

# %%
pd.read_excel(/content/drive/MyDrive/programaria/Copy)
